# %% [markdown]
# # # 📊 Matplotlib Basics – Day 8
# **Goal:** Learn basic plots – Line, Bar, Scatter, and Pie using Matplotlib.

# %% [markdown]
# # 1. Import Libraries

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# # 2. Line Plot

# %%
x = [1, 2, 3, 4, 5]
y = [2, 4, 6, 8, 10]

plt.plot(x, y, color="blue", marker="o")
plt.title("Line Plot Example")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.show()

# %% [markdown]
# # 3. Bar Chart

# %%
categories = ["A", "B", "C", "D"]
values = [10, 20, 15, 30]

plt.bar(categories, values, color="orange")
plt.title("Bar Chart Example")
plt.xlabel("Categories")
plt.ylabel("Values")
plt.show()

# %% [markdown]
# # 4. Scatter Plot

# %%
x = [5, 7, 8, 7, 6, 9, 5, 6]
y = [99, 86, 87, 88, 100, 86, 103, 87]

plt.scatter(x, y, color="green")
plt.title("Scatter Plot Example")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.show()

# %% [markdown]
# # 5. Pie Chart

# %%
sizes = [25, 35, 20, 20]
labels = ["A", "B", "C", "D"]

plt.pie(sizes, labels=labels, autopct="%1.1f%%", startangle=140)
plt.title("Pie Chart Example")
plt.show()

# %% [markdown]
# # ✅ Summary (Day 8):
#
# - Line Plot → show trends
# - Bar Chart → compare categories
# - Scatter Plot → relationships
# - Pie Chart → proportions
