# %% [markdown]
# # 🌊 Seaborn Basics – Day 10
# **Goal:** Learn histograms, boxplots, and heatmaps.

# %% [markdown]
# # 1. Import Libraries

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Built-in dataset
tips = sns.load_dataset("tips")
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# # 2. Histogram

# %%
sns.histplot(tips["total_bill"], bins=20, kde=True, color="blue")
plt.title("Histogram of Total Bill")
plt.show()

# %% [markdown]
# # 3. Boxplot

# %%
sns.boxplot(x="day", y="total_bill", data=tips, palette="Set2")
plt.title("Boxplot of Total Bill by Day")
plt.show()
# Out:
# C:\Users\Farhan Diwan\AppData\Local\Temp\ipykernel_16300\3639073386.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="day", y="total_bill", data=tips, palette="Set2")

# %% [markdown]
# # 4. Heatmap

# %%
corr = tips.corr(numeric_only=True)
sns.heatmap(corr, annot=True, cmap="coolwarm")
plt.title("Correlation Heatmap")
plt.show()

# %% [markdown]
# # ✅ Summary (Day 10):
#
# - Histogram → distribution
# - Boxplot → outliers
# - Heatmap → correlation
